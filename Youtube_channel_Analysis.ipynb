# %% [markdown]
# <a href="https://colab.research.google.com/github/channdankumar/Youtube_channel_Analysis/blob/main/Youtube_channel_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Youtube Top 5000 Channel Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("/content/top-5000-youtube-channels.csv")

# %%
df.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %% [markdown]
# **Display first 5 rows of this dataset**

# %%
df.head(6)
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
# 5  6th  A++                   Movieclips         30243    17149705
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433
# 5  16618094724

# %% [markdown]
# **Display last 5 rows of this dataset**

# %%
df.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %% [markdown]
# **Find shape of our Dataset (Number or Rows and Number of Columns)**

# %%
df.shape
# Out:
# (5000, 6)

# %% [markdown]
# **Get information about our Dataset like Total Number Rows,Total Number of Columns,Dataset of each Columns**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %% [markdown]
# **Get Over all Statistics about the Dataframe**

# %%
df.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %% [markdown]
# Find Columns of our Dataset

# %%
df.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %% [markdown]
# **Find the Dublicate**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Check Null Values in the Dataset**

# %%
df.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank             5000
# Grade               6
# Channel name     4993
# Video Uploads    2286
# Subscribers      4612
# Video views      5000
# dtype: int64

# %% [markdown]
# **Data Cleaning (Video Upload and Subscriber)**

# %%
df["video uploads"] = df["video uploads"].astype("int64")

# %%
df["Subscriber"] = df["Subscriber"].astype("int64")

# %%
df.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %% [markdown]
# **Find Average Views for Each Channel**

# %% [markdown]
# **Find Correlation Matrix**

# %%
df.corr()
# Out:
#              Video views
# Video views          1.0

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', '\xa0 ', 'A- ', 'B+ '], dtype=object)

# %%
df['Grade'].value_counts()
# Out:
# B+      2956
# A-      1024
# A        963
# A+        41
# A++       10
#            6
# Name: Grade, dtype: int64

# %%
df['Grade'].value_counts().index
# Out:
# Index(['B+ ', 'A- ', 'A ', 'A+ ', 'A++ ', '  '], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 4))
sns.countplot(x='Grade', data=df, palette='hls')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.pie(df['Grade'].value_counts(), labels=df['Grade'].value_counts().index, autopct='%1.1f%%')
hfont = {'fontname': 'serif', 'weight': 'bold'}
plt.title('Grade', size=20, **hfont)
plt.show()

# %%
df['Rank'].value_counts().index
# Out:
# Index(['1st', '3,331st', '3,338th', '3,337th', '3,336th', '3,335th', '3,334th',
#        '3,333rd', '3,332nd', '3,330th',
#        ...
#        '1,672nd', '1,671st', '1,670th', '1,669th', '1,668th', '1,667th',
#        '1,666th', '1,665th', '1,664th', '5,000th'],
#       dtype='object', length=5000)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 5))
sns.countplot(x='Channel name', data=df, palette='hls')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.pie(df['Channel name'].value_counts(), labels=df['Channel name'].value_counts().index, autopct='%1.1f%%')
hfont = {'fontname': 'serif', 'weight': 'bold'}
plt.title('Channel name', size=20, **hfont)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.pie(df[''].value_counts(), labels=df['Channel name'].value_counts().index, autopct='%1.1f%%')
hfont = {'fontname': 'serif', 'weight': 'bold'}
plt.title('Channel name', size=20, **hfont)
plt.show()

# %% [markdown]
#                         **Thank you (BY : Chandan Kumar)**
